# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
resp_Status_code=requests.get('https://www.google.com/search?q=%EB%84%A4%EC%9D%B4%EB%B2%84+%EC%A6%9D%EA%B6%8C&rlz=1C1CHBD_koKR1083KR1091&oq=%EB%84%A4%EC%9D%B4%EB%B2%84+%EC%A6%9D%EA%B6%8C&gs_lcrp=EgZjaHJvbWUyCQgAEEUYORiABDIHCAEQABiABDIHCAIQABiABDIHCAMQABiABDIHCAQQABiABDIHCAUQABiABDIHCAYQABiABDINCAcQABiDARixAxiABDIHCAgQABiABNIBCDMyNzJqMGo3qAIIsAIB&sourceid=chrome&ie=UTF-8')

# %%
resp_Status_code.content
# Out:
# b'<!doctype html><html lang="ko"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>&#45348;&#51060;&#48260; &#51613;&#44428; - Google &#44160;&#49353;</title><script nonce="URNEx-6sb_sGKmPwqb7kJA">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){var a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floo
# ...

# %%
bs=BeautifulSoup(resp_Status_code.content,'lxml')

# %%
bs.find('div',{'jsname':'ihlZgd'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 bs.find('div',{'span':'ihlZgd'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(bs.find('span',{'jsname':'vWLAgc'}))
# Out:
# Google
