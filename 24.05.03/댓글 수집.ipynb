# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
resp_Status_code_reply=requests.get('https://n.news.naver.com/mnews/article/comment/022/0003285339?sid=100')

# %%
resp_Status_code_reply
# Out:
# <Response [200]>

# %%
resp_Status_code_reply.content
# Out:
# b'<!doctype html>\n<html lang="ko" data-useragent="python-requests/2.31.0">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="[\xeb\xb0\x95\xec\x88\x98\xec\xb0\xac\xec\x9d\x98 \xe8\xbb\x8d]\xe2\x80\x9c\xeb\x88\x84\xea\xb0\x80 \xea\xb5\xb0\xeb\x8c\x80\xea\xb0\x80\xea\xb2\xa0\xeb\x82\x98\xe2\x80\x9d\xe2\x80\xa6\xeb\x8c\x80\xec\xb2\xb4\xeb\xb3\xb5\xeb\xac\xb4, \xea\xb5\xb0 \xeb\x92\xa4\xed\x9d\x94\xeb\x93\xa4 \xed\x8f\xad\xed\x83\x84\xeb\x90\xa0\xea\xb9\x8c">\n\t\t<meta property="og:type" content="article">\n\t\t<meta property="og:url" content="https://n.news.naver.com/mnews/article/022/0003285339?sid&#x3D;100">\n\t\t<meta property="og:image" content="https://imgnews.pstatic.net/image/022/2018/06/30/20180629005472_0_20180630101606662.jpg?type&#x3D;w800">\n\t\t<meta prop
# ...

# %%
bs=BeautifulSoup(resp_Status_code_reply.content,'lxml')

# %%
bs.find('div',{'class':'u_cbox_content_wrap'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 bs.find('div',{'class':'u_cbox_content_wrap'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
help(bs.find('div',{'class':'u_cbox_content_wrap'}))
# Out:
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
type(bs.find('div',{'class':'u_cbox_content_wrap'}))
# Out:
# NoneType

# %%
bs.find('div',{'class':'u_cbox_text_wrap'}).find('span',{'class':'u_cbox_contents'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 bs.find('div',{'class':'u_cbox_text_wrap'}).find('span',{'class':'u_cbox_contents'}).text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
comment_div = bs.find('div', {'class': 'u_cbox_text_wrap'})

# %%
comment_text = comment_div.find('span', {'class': 'u_cbox_contents'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 comment_text = comment_div.find('span', {'class': 'u_cbox_contents'}).text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
comment_div = bs.find('div', {'class': 'u_cbox_text_wrap'}).find('span', {'class': 'u_cbox_contents'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 comment_div = bs.find('div', {'class': 'u_cbox_text_wrap'}).find('span', {'class': 'u_cbox_contents'}).text
#
# AttributeError: 'NoneType' object has no attribute 'find'
